# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins.head(100)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# ..     ...        ...             ...            ...                ...
# 95  Adelie      Dream            40.8           18.9              208.0
# 96  Adelie      Dream            38.1           18.6              190.0
# 97  Adelie      Dream            40.3           18.5              196.0
# 98  Adelie      Dream            33.1           16.1              178.0
# 99  Adelie      Dream            43.2           18.5              192.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# ...

# %%
ax = sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm')

# %%
fg = sns.relplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', kind='scatter')

# %%
sns.relplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', kind='scatter', col='sex', hue='species')

# %%
sns.relplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', kind='scatter', col='sex', hue='island')

# %%
flights = sns.load_dataset('flights')

# %%
flights

# %%
sns.relplot(data=flights, y='passengers', x='year', kind='line')

# %%
sns.displot(data=penguins, x='body_mass_g', kind='hist', bins=20)

# %%
sns.displot(data=penguins, x='body_mass_g', kind='hist', bins=20, hue='island')

# %%
sns.displot(data=penguins, x='body_mass_g', kind='hist', bins=20, hue='species', col='sex', row='island')

# %%
sns.displot(data=penguins, x='body_mass_g', kind='kde')

# %%
sns.displot(data=penguins, x='body_mass_g', y='bill_length_mm', cbar=True)

# %%
df = pd.read_csv('train.csv')
df.head(25)
# Out:
#     PassengerId  Survived  Pclass               Name     Sex    Age  SibSp  \
# 0             0         1       1   Oconnor, Frankie    male    NaN      2
# 1             1         0       3        Bryan, Drew    male    NaN      0
# 2             2         0       3     Owens, Kenneth    male   0.33      1
# 3             3         0       3      Kramer, James    male  19.00      0
# 4             4         1       3      Bond, Michael    male  25.00      0
# 5             5         0       2  Sassano, Jonathan    male  35.00      0
# 6             6         0       3       Conway, Jose    male   7.00      0
# 7             7         1       3      Werner, Linda  female   6.00      1
# 8             8         0       1   Wardlaw, Michael    male  27.00      2
# 9             9         0       2       Greigo, Rudy    male  66.00      0
# 10           10         0       3   Nichols, William    male  31.00      0
# ...

# %%
sns.displot(data=df, x='Survived', kind='hist', bins=20, col='Sex')

# %%
sns.displot(data=df, x='Survived', y='Age', cbar=True)

# %%
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.displot(data=df, x='Age', kind='hist', bins=20)

# %%
sns.displot(data=df, x='Fare', kind='hist', bins=20)

# %%
sns.displot(data=df, x='Pclass', kind='hist')

# %%
sns.displot(data=df, x='Survived', kind='hist', bins=20, hue='Pclass', col='Sex')

# %%
# sns.catplot(data=df, kind="swarm", x="Pclass", y="Fare", hue="Sex")
